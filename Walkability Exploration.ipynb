# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Load the data
walkability_df = pd.read_csv('Resources/EPA_SmartLocationDatabase_V3_Jan_2021_Final.csv')

# %%
walkability_df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220740 entries, 0 to 220739
# Data columns (total 117 columns):
#  #    Column        Dtype
# ---   ------        -----
#  0    OBJECTID      int64
#  1    GEOID10       float64
#  2    GEOID20       float64
#  3    STATEFP       int64
#  4    COUNTYFP      int64
#  5    TRACTCE       int64
#  6    BLKGRPCE      int64
#  7    CSA           float64
#  8    CSA_Name      object
#  9    CBSA          float64
#  10   CBSA_Name     object
#  11   CBSA_POP      int64
#  12   CBSA_EMP      int64
#  13   CBSA_WRK      int64
#  14   Ac_Total      float64
#  15   Ac_Water      float64
#  16   Ac_Land       float64
#  17   Ac_Unpr       float64
#  18   TotPop        int64
#  19   CountHU       float64
#  20   HH            float64
#  21   P_WrkAge      float64
#  22   AutoOwn0      int64
#  23   Pct_AO0       float64
#  24   AutoOwn1      int64
#  25   Pct_AO1       float64
#  26   AutoOwn2p     int64
#  27   Pct_AO2p      float64
#  28   Workers       int64
#  29   R_LowWageWk   int64
#  30   R_MedWageWk   int64
#  31   R_HiWageWk    int64
#  32   R_PCTLOWWAGE  float64
#  33   TotEmp        int64
#  34   E5_Ret        int64
#  35   E5_Off        int64
#  36   E5_Ind        int64
#  37   E5_Svc        int64
#  38   E5_Ent        int64
#  39   E8_Ret        int64
#  40   E8_off        int64
#  41   E8_Ind        int64
#  42   E8_Svc        int64
#  43   E8_Ent        int64
#  44   E8_Ed         int64
#  45   E8_Hlth       int64
#  46   E8_Pub        int64
#  47   E_LowWageWk   int64
#  48   E_MedWageWk   int64
#  49   E_HiWageWk    int64
#  50   E_PctLowWage  float64
#  51   D1A           float64
#  52   D1B           float64
#  53   D1C           float64
#  54   D1C5_RET      float64
#  55   D1C5_OFF      float64
#  56   D1C5_IND      float64
#  57   D1C5_SVC      float64
#  58   D1C5_ENT      float64
#  59   D1C8_RET      float64
#  60   D1C8_OFF      float64
#  61   D1C8_IND      float64
#  62   D1C8_SVC      float64
#  63   D1C8_ENT      float64
#  64   D1C8_ED       float64
#  65   D1C8_HLTH     float64
#  66   D1C8_PUB      float64
#  67   D1D           float64
#  68   D1_FLAG       int64
#  69   D2A_JPHH      float64
#  70   D2B_E5MIX     float64
#  71   D2B_E5MIXA    float64
#  72   D2B_E8MIX     float64
#  73   D2B_E8MIXA    float64
#  74   D2A_EPHHM     float64
#  75   D2C_TRPMX1    float64
#  76   D2C_TRPMX2    float64
#  77   D2C_TRIPEQ    float64
#  78   D2R_JOBPOP    float64
#  79   D2R_WRKEMP    float64
#  80   D2A_WRKEMP    float64
#  81   D2C_WREMLX    float64
#  82   D3A           float64
#  83   D3AAO         float64
#  84   D3AMM         float64
#  85   D3APO         float64
#  86   D3B           float64
#  87   D3BAO         float64
#  88   D3BMM3        float64
#  89   D3BMM4        float64
#  90   D3BPO3        float64
#  91   D3BPO4        float64
#  92   D4A           float64
#  93   D4B025        float64
#  94   D4B050        float64
#  95   D4C           float64
#  96   D4D           float64
#  97   D4E           float64
#  98   D5AR          int64
#  99   D5AE          int64
#  100  D5BR          int64
#  101  D5BE          int64
#  102  D5CR          float64
#  103  D5CRI         float64
#  104  D5CE          float64
#  105  D5CEI         float64
#  106  D5DR          float64
#  107  D5DRI         float64
#  108  D5DE          float64
#  109  D5DEI         float64
#  110  D2A_Ranked    int64
#  111  D2B_Ranked    int64
#  112  D3B_Ranked    int64
#  113  D4A_Ranked    int64
#  114  NatWalkInd    float64
#  115  Shape_Length  float64
#  116  Shape_Area    float64
# dtypes: float64(73), int64(42), object(2)
# memory usage: 197.0+ MB

# %%
walkability_df.columns
# Out:
# Index(['OBJECTID', 'GEOID10', 'GEOID20', 'STATEFP', 'COUNTYFP', 'TRACTCE',
#        'BLKGRPCE', 'CSA', 'CSA_Name', 'CBSA',
#        ...
#        'D5DRI', 'D5DE', 'D5DEI', 'D2A_Ranked', 'D2B_Ranked', 'D3B_Ranked',
#        'D4A_Ranked', 'NatWalkInd', 'Shape_Length', 'Shape_Area'],
#       dtype='object', length=117)

# %%
walkability_df.rename(columns={'D2A_Ranked':'Quantile Ranked Order D2A', 'D2B_Ranked':'Quantile Ranked Order D2B', 'D3B_Ranked':'Quantile Ranked Order D3B', 'D4A_Ranked':'Quantile Ranked Order D4A'},inplace=True)
walkability_df.head(10)
# Out:
#    OBJECTID       GEOID10       GEOID20  STATEFP  COUNTYFP  TRACTCE  BLKGRPCE  \
# 0         1  4.811300e+11  4.811300e+11       48       113     7825         4
# 1         2  4.811300e+11  4.811300e+11       48       113     7825         2
# 2         3  4.811300e+11  4.811300e+11       48       113     7825         3
# 3         4  4.811300e+11  4.811300e+11       48       113     7824         1
# 4         5  4.811300e+11  4.811300e+11       48       113     7824         2
# 5         6  4.811300e+11  4.811300e+11       48       113     7827         1
# 6         7  4.811300e+11  4.811300e+11       48       113     9301         2
# 7         8  4.811300e+11  4.811300e+11       48       113     1102         2
# 8         9  4.811300e+11  4.811300e+11       48       113    11401         2
# 9        10  4.811300e+11  4.811300e+11       48       113    11401         3
#
#      CSA                  CSA_Name     CBSA  ...     D5DRI      D5DE  \
# 0  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...  0.184697  0.000476
# 1  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...  0.323221  0.000801
# 2  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...  0.314628  0.000736
# 3  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...  0.229821  0.000708
# 4  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...  0.164863  0.000433
# 5  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...  0.189063  0.000467
# 6  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...  0.012107  0.000184
# 7  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...  0.375864  0.001031
# 8  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...  0.000030  0.000005
# 9  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...  0.000012  0.000006
#
#       D5DEI  Quantile Ranked Order D2A  Quantile Ranked Order D2B  \
# 0  0.137707                          6                         14
# 1  0.231868                          3                         10
# 2  0.213146                          1                          1
# 3  0.205018                         16                         10
# 4  0.125296                          4                          7
# 5  0.135336                          1                          4
# 6  0.053166                          1                          1
# 7  0.298647                          9                         12
# 8  0.001318                          3                          2
# 9  0.001745                          1                          1
#
#    Quantile Ranked Order D3B  Quantile Ranked Order D4A  NatWalkInd  \
# 0                         15                         17   14.000000
# 1                         12                         14   10.833333
# 2                          7                         17    8.333333
# 3                         17                         17   15.666667
# 4                         11                         14   10.166667
# 5                          5                         13    6.833333
# 6                         10                         13    8.000000
# 7                         13                         16   13.166667
# 8                         11                         18   10.500000
# 9                         10                         15    8.666667
#
#    Shape_Length    Shape_Area
# 0   3110.360820  2.978361e+05
# 1   3519.469110  4.849451e+05
# 2   1697.091802  1.067059e+05
# 3   2922.609204  4.818284e+05
# 4   3731.971773  6.876848e+05
# 5   3109.651786  2.051268e+05
# 6   4345.799339  8.119811e+05
# 7   2248.148479  2.589736e+05
# 8   8246.622195  2.479375e+06
# 9   3669.658355  7.574020e+05
#
# [10 rows x 117 columns]

# %%
walkability_df.rename(columns={'NatWalkind':'Weighted Sum of Ranked Values', 'D5DRI':'Regional Centrality Index', 'Shape_Length':'Shape Length', 'Shape_Area':'Shape Area', 'STATEFP':'State FIPS Code', 'COUNTYFP':'County FIPS Code', 'TRACTCE':'Census FIPS Code', 'BLKGRPCE':'CEBLKGRP FIPS Code'},inplace=True)
walkability_df.head(10)
# Out:
#    OBJECTID       GEOID10       GEOID20  State FIPS Code  County FIPS Code  \
# 0         1  4.811300e+11  4.811300e+11               48               113
# 1         2  4.811300e+11  4.811300e+11               48               113
# 2         3  4.811300e+11  4.811300e+11               48               113
# 3         4  4.811300e+11  4.811300e+11               48               113
# 4         5  4.811300e+11  4.811300e+11               48               113
# 5         6  4.811300e+11  4.811300e+11               48               113
# 6         7  4.811300e+11  4.811300e+11               48               113
# 7         8  4.811300e+11  4.811300e+11               48               113
# 8         9  4.811300e+11  4.811300e+11               48               113
# 9        10  4.811300e+11  4.811300e+11               48               113
#
#    Census FIPS Code  CEBLKGRP FIPS Code    CSA                  CSA_Name  \
# 0              7825                   4  206.0  Dallas-Fort Worth, TX-OK
# 1              7825                   2  206.0  Dallas-Fort Worth, TX-OK
# 2              7825                   3  206.0  Dallas-Fort Worth, TX-OK
# 3              7824                   1  206.0  Dallas-Fort Worth, TX-OK
# 4              7824                   2  206.0  Dallas-Fort Worth, TX-OK
# 5              7827                   1  206.0  Dallas-Fort Worth, TX-OK
# 6              9301                   2  206.0  Dallas-Fort Worth, TX-OK
# 7              1102                   2  206.0  Dallas-Fort Worth, TX-OK
# 8             11401                   2  206.0  Dallas-Fort Worth, TX-OK
# 9             11401                   3  206.0  Dallas-Fort Worth, TX-OK
#
#       CBSA  ... Regional Centrality Index      D5DE     D5DEI  \
# 0  19100.0  ...                  0.184697  0.000476  0.137707
# 1  19100.0  ...                  0.323221  0.000801  0.231868
# 2  19100.0  ...                  0.314628  0.000736  0.213146
# 3  19100.0  ...                  0.229821  0.000708  0.205018
# 4  19100.0  ...                  0.164863  0.000433  0.125296
# 5  19100.0  ...                  0.189063  0.000467  0.135336
# 6  19100.0  ...                  0.012107  0.000184  0.053166
# 7  19100.0  ...                  0.375864  0.001031  0.298647
# 8  19100.0  ...                  0.000030  0.000005  0.001318
# 9  19100.0  ...                  0.000012  0.000006  0.001745
#
#    Quantile Ranked Order D2A  Quantile Ranked Order D2B  \
# 0                          6                         14
# 1                          3                         10
# 2                          1                          1
# 3                         16                         10
# 4                          4                          7
# 5                          1                          4
# 6                          1                          1
# 7                          9                         12
# 8                          3                          2
# 9                          1                          1
#
#    Quantile Ranked Order D3B  Quantile Ranked Order D4A  NatWalkInd  \
# 0                         15                         17   14.000000
# 1                         12                         14   10.833333
# 2                          7                         17    8.333333
# 3                         17                         17   15.666667
# 4                         11                         14   10.166667
# 5                          5                         13    6.833333
# 6                         10                         13    8.000000
# 7                         13                         16   13.166667
# 8                         11                         18   10.500000
# 9                         10                         15    8.666667
#
#    Shape Length    Shape Area
# 0   3110.360820  2.978361e+05
# 1   3519.469110  4.849451e+05
# 2   1697.091802  1.067059e+05
# 3   2922.609204  4.818284e+05
# 4   3731.971773  6.876848e+05
# 5   3109.651786  2.051268e+05
# 6   4345.799339  8.119811e+05
# 7   2248.148479  2.589736e+05
# 8   8246.622195  2.479375e+06
# 9   3669.658355  7.574020e+05
#
# [10 rows x 117 columns]

# %% [markdown]
# w = block group’s ranked score for intersection density
# x = block group’s ranked score for proximity to transit stops
# y = block group’s ranked score for employment mix
# z = block group’s ranked score for employment and household mix
#
# Final National Walkability Index score = w/3+x/3+y/6+z/6
