# %%
import requests
import pandas as pd
import os
import folium
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Access the API key
api_key = os.getenv('API_KEY_FOR_EV_STATION')
base_url = "https://developer.nrel.gov/api/alt-fuel-stations/v1.json"

def generate_zip_codes(start, end):
    return [str(zip_code) for zip_code in range(start, end + 1)]

zip_codes = generate_zip_codes(10451, 10475)

def fetch_data_for_zip_codes(zip_codes):
    results = []

    for zip_code in zip_codes:
        params = {
            'api_key': api_key,
            'state': 'NY',
            'zip': zip_code,
            'limit': 10  # Adjust limit as necessary
        }
        response = requests.get(base_url, params=params)

        if response.status_code == 200:
            json_data = response.json()
            stations = json_data['fuel_stations']
            for station in stations:
                results.append({
                    'zip_code': zip_code,
                    'city': station.get('city'),
                    'latitude': station.get('latitude'),
                    'longitude': station.get('longitude'),
                    'total_results': json_data['total_results']
                })
        else:
            print(f"Failed to fetch data for ZIP code {zip_code}: Status code {response.status_code}")
        
    return results

data = fetch_data_for_zip_codes(zip_codes)
df = pd.DataFrame(data)


# Create a map centered around New York
ny_map = folium.Map(location=[40.730610, -73.935242], zoom_start=12)

# Add markers to the map
for idx, row in df.iterrows():
    if pd.notnull(row['latitude']) and pd.notnull(row['longitude']):
        folium.Marker([row['latitude'], row['longitude']],
                      popup=f"City: {row['city']}, ZIP: {row['zip_code']}").add_to(ny_map)

# Display the map
ny_map.save('NY_EV_Stations.html')
ny_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81b8cd301ef40c3f870ca41b291fea7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81b8cd301ef40c3f870ca41b291fea7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81b8cd301ef40c3f870ca41b291fea7b = L.map(
#                 &quot;map_81b8cd301ef40c3f870ca41b291fea7b&quot;,
#                 {
#                     center: [40.73061, -73.935242],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2026c7b1312e044c4cc90d2af5bcfd77 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2026c7b1312e044c4cc90d2af5bcfd77.addTo(map_81b8cd301ef40c3f870ca41b291fea7b);
#
#
#             var marker_ef684b0c0c6f6ebb15ddc925fcf96478 = L.marker(
#                 [40.822142, -73.931128],
#                 {}
#             ).addTo(map_81b8cd301ef40c3f870ca41b291fea7b);
#
#
#         var popup_ad933bd74cc2a541d59f50430fa3e39a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0cc9eb3557525342321b3c8fa76703b8 = $(`&lt;div id=&quot;html_0cc9eb3557525342321b3c8fa76703b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Bronx, ZIP: 10451&lt;/div&gt;`)[0];
#                 popup_ad933bd74cc2a541d59f50430fa3e39a.setContent(html_0cc9eb3557525342321b3c8fa76703b8);
#
#
#
#         marker_ef684b0c0c6f6ebb15ddc925fcf96478.bindPopup(popup_ad933bd74cc2a541d59f50430fa3e39a)
#         ;
#
#
#
#
#             var marker_139541df15056a15c5fd52e83954a8af = L.marker(
#                 [40.80733842809466, -73.9300472661853],
#                 {}
#             ).addTo(map_81b8cd301ef40c3f870ca41b291fea7b);
#
#
#         var popup_0f931f23c0ca7f1d6bbc9104c9bcd11f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee10b07c70ca0ac04ce7fb603fbaca26 = $(`&lt;div id=&quot;html_ee10b07c70ca0ac04ce7fb603fbaca26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Bronx, ZIP: 10454&lt;/div&gt;`)[0];
#                 popup_0f931f23c0ca7f1d6bbc9104c9bcd11f.setContent(html_ee10b07c70ca0ac04ce7fb603fbaca26);
#
#
#
#         marker_139541df15056a15c5fd52e83954a8af.bindPopup(popup_0f931f23c0ca7f1d6bbc9104c9bcd11f)
#         ;
#
#
#
#
#             var marker_efe6904e88cb999dca8d518dfa049ced = L.marker(
#                 [40.808151, -73.902589],
#                 {}
#             ).addTo(map_81b8cd301ef40c3f870ca41b291fea7b);
#
#
#         var popup_5ddacd0a164a8052913a7ee0b35cadf6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71be37eaa737106591bcd51cde00182c = $(`&lt;div id=&quot;html_71be37eaa737106591bcd51cde00182c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Bronx, ZIP: 10455&lt;/div&gt;`)[0];
#                 popup_5ddacd0a164a8052913a7ee0b35cadf6.setContent(html_71be37eaa737106591bcd51cde00182c);
#
#
#
#         marker_efe6904e88cb999dca8d518dfa049ced.bindPopup(popup_5ddacd0a164a8052913a7ee0b35cadf6)
#         ;
#
#
#
#
#             var marker_fcd4a02b063d9f05d1bd9c64b10ed1ed = L.marker(
#                 [40.80549, -73.90049],
#                 {}
#             ).addTo(map_81b8cd301ef40c3f870ca41b291fea7b);
#
#
#         var popup_462927854195f5b1bfe3cc4fb5aa4d64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5aa9c12dbf700400cf9d2fd02cfac90 = $(`&lt;div id=&quot;html_e5aa9c12dbf700400cf9d2fd02cfac90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Bronx, ZIP: 10455&lt;/div&gt;`)[0];
#                 popup_462927854195f5b1bfe3cc4fb5aa4d64.setContent(html_e5aa9c12dbf700400cf9d2fd02cfac90);
#
#
#
#         marker_fcd4a02b063d9f05d1bd9c64b10ed1ed.bindPopup(popup_462927854195f5b1bfe3cc4fb5aa4d64)
#         ;
#
#
#
#
#             var marker_7a11836ed579655e53c8bf7fa24e19bf = L.marker(
#                 [40.86095, -73.889379],
#                 {}
#             ).addTo(map_81b8cd301ef40c3f870ca41b291fea7b);
#
#
#         var popup_475827c7017e6cb2211af2092dce9211 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0add11d68927b426eef75afa67365516 = $(`&lt;div id=&quot;html_0add11d68927b426eef75afa67365516&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Bronx, ZIP: 10458&lt;/div&gt;`)[0];
#                 popup_475827c7017e6cb2211af2092dce9211.setContent(html_0add11d68927b426eef75afa67365516);
#
#
#
#         marker_7a11836ed579655e53c8bf7fa24e19bf.bindPopup(popup_475827c7017e6cb2211af2092dce9211)
#         ;
#
#
#
#
#             var marker_2b2c5619d5976523139a4bb7923a9c89 = L.marker(
#                 [40.8732909, -73.884626],

# %%
df
# Out:
#    zip_code            city   latitude  longitude  total_results
# 0     10451           Bronx  40.822142 -73.931128              1
# 1     10454           Bronx  40.807338 -73.930047              1
# 2     10455           Bronx  40.808151 -73.902589              2
# 3     10455           Bronx  40.805490 -73.900490              2
# 4     10458           Bronx  40.860950 -73.889379              2
# 5     10458           Bronx  40.873291 -73.884626              2
# 6     10459           Bronx  40.822935 -73.890483              3
# 7     10459       The Bronx  40.831638 -73.891659              3
# 8     10459       The Bronx  40.808441 -73.918110              3
# 9     10460           Bronx  40.850018 -73.878128              5
# 10    10460           Bronx  40.838672 -73.877566              5
# 11    10460           Bronx  40.846205 -73.876513              5
# 12    10460           Bronx  40.850625 -73.881132              5
# 13    10460           Bronx  40.846612 -73.876323              5
# 14    10462           Bronx  40.844188 -73.861572              2
# 15    10462           Bronx  40.831740 -73.844850              2
# 16    10463           Bronx  40.878532 -73.916201              4
# 17    10463           Bronx  40.880142 -73.907385              4
# 18    10463           Bronx  40.888461 -73.899119              4
# 19    10463           Bronx  40.879501 -73.903603              4
# 20    10465           Bronx  40.812459 -73.834470              1
# 21    10466           Bronx  40.894881 -73.860525              2
# 22    10466           Bronx  40.882786 -73.841986              2
# 23    10467        New York  40.879718 -73.880394              5
# 24    10467           Bronx  40.879413 -73.875485              5
# 25    10467           Bronx  40.892423 -73.882373              5
# 26    10467           Bronx  40.882337 -73.880265              5
# 27    10467        New York  40.883002 -73.880698              5
# 28    10468           Bronx  40.867403 -73.906405              4
# 29    10468           Bronx  40.863340 -73.900066              4
# 30    10468      West Bronx  40.872524 -73.890564              4
# 31    10468           Bronx  40.875421 -73.893941              4
# 32    10469           Bronx  40.876952 -73.845534              2
# 33    10469  Williamsbridge  40.874265 -73.852887              2
# 34    10470           Bronx  40.905461 -73.849791              1
# 35    10471       Riverdale  40.908654 -73.905897              4
# 36    10471       Riverdale  40.908720 -73.905883              4
# 37    10471           Bronx  40.887340 -73.895260              4
# 38    10471       The Bronx  40.892469 -73.909115              4
# 39    10472           Bronx  40.830510 -73.874370              1
# 40    10473           Bronx  40.822890 -73.841375              2
# 41    10473           Bronx  40.821451 -73.877642              2
# 42    10474           Bronx  40.805695 -73.880803              1
# 43    10475           Bronx  40.863231 -73.828839              2
# 44    10475           Bronx  40.869205 -73.831633              2
